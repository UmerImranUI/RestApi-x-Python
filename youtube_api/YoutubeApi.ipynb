# %%
api_key='AIzaSyBG3HK605J0WgnNLiUjRu8rLfatt_1CdLY'

# %%
from apiclient.discovery import build

# %%
youtube=build('youtube', 'v3', developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req=youtube.search().list(q='indian pythonista', part='snippet', type='video', maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res=req.execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'm4C7mAqBSJvajLfxIDUsDRc-7jM',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'PK',
#  'pageInfo': {'totalResults': 9698, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'EFVA2qg5PL4cjMhvOKQASoELDGQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'R4Oz8JUuM4s'},
#    'snippet': {'publishedAt': '2020-05-18T08:23:29Z',
#     'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg',
#     'title': 'Making multiple HTTP requests using Python (synchronous, multiprocessing, multithreading, asyncio)',
#     'description': 'In this video, we try to explore various ways using which we can execute multiple HTTP requests using Python. We try ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
res['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'EFVA2qg5PL4cjMhvOKQASoELDGQ',
#  'id': {'kind': 'youtube#video', 'videoId': 'R4Oz8JUuM4s'},
#  'snippet': {'publishedAt': '2020-05-18T08:23:29Z',
#   'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg',
#   'title': 'Making multiple HTTP requests using Python (synchronous, multiprocessing, multithreading, asyncio)',
#   'description': 'In this video, we try to explore various ways using which we can execute multiple HTTP requests using Python. We try ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Indian Pythonista',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2020-05-18T08:23:29Z'}}

# %%
for item in res['items']:
    print(item['snippet'])
# Out:
# {'publishedAt': '2020-05-18T08:23:29Z', 'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg', 'title': 'Making multiple HTTP requests using Python (synchronous, multiprocessing, multithreading, asyncio)', 'description': 'In this video, we try to explore various ways using which we can execute multiple HTTP requests using Python. We try ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/R4Oz8JUuM4s/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Indian Pythonista', 'liveBroadcastContent': 'none', 'publishTime': '2020-05-18T08:23:29Z'}
# ...

# %%
xxxxxxxxxxxxxxxxxxxxxxxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [89], in <cell line: 1>()
# ----> 1 xxxxxxxxxxxxxxxxxxxxxxxx
#
# NameError: name 'xxxxxxxxxxxxxxxxxxxxxxxx' is not defined

# %%
req=youtube.search().list(q='python programming', part='snippet', type='video', maxResults=50, publishedAfter=start_time, publishedBefore=end_time).execute()

# %%
from datetime import datetime

# %%
start_time=datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time=datetime(year=2008, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
req
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'fl1uUFRSaStfdZYyJvw8-lrMM3k',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'PK',
#  'pageInfo': {'totalResults': 10007, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'swMkQ-8DCFDkbSABxYGa6OTMh2o',
#    'id': {'kind': 'youtube#video', 'videoId': '29mq1Bn52GY'},
#    'snippet': {'publishedAt': '2007-12-31T21:45:31Z',
#     'channelId': 'UCNN08Liw2TPLSy_STQcWIkQ',
#     'title': 'Python tutorial for beginners',
#     'description': "Thank you Below is the C2F conversion calculator, keep in mind it is only 4 lines long. def C2F(): Celsius = input('Enter degrees in ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/29mq1Bn52GY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/29mq1Bn52GY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/29mq1Bn52GY/hqdefault.jpg',
# ...

# %%
for item in sorted(req['items'], key=lambda x:x['snippet']['publishedAt']):
    print(item['snippet']['title'], item['snippet']['publishedAt'], item['id']['videoId'])
# Out:
# Monty Python - we used to dream about living in a corridor 2006-06-17T20:39:54Z WRxjqOcvxoE
# Monty Python - Philosophers&#39; World Cup 2006-11-16T14:31:18Z 92vV3QGagck
# Drunk tilted Room Sketch 2006-11-28T07:28:13Z YyqEjatCSe0
# Steve Irwin Greatest TV event. Rare Snake Bite. Sunshine TV. 2007-01-08T07:24:40Z dnfn6rV4sL0
# ZiYa Plugin 2007-01-14T20:26:03Z axIMmMHdXzo
# Rubyology ScreenCast 1 2007-03-31T15:41:17Z irkKLFpbG4M
# Open-laszlo basic tutorial 2007-05-01T15:00:15Z qdUnHL-FaQM
# msn nudge and end 2007-05-20T08:22:31Z LpUu2eyyPQM
# John Cleese and Rowan Atkinson - Beekeeping 2007-05-21T01:43:37Z OGFz9gt0-Fc
# OpenGL Tutorial #3: Color 2007-05-31T13:47:04Z kazAxuEx3FI
# Google Developers Day US - Python Design Patterns 2007-06-05T02:48:10Z 0vJJlVBVTFg
# OpenGL Tutorial #4: Lighting, Part 2 of 2 2007-06-13T03:24:52Z eIyFhSDQeIs
# Lesson 3 - Interactive Programming 2007-07-16T02:31:12Z b0rx7jh50DM
# ...

# %%
xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# NameError: name 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' is not defined

# %%
 res=youtube.channels().list(id='UCkUq-s6z57uJFUFBvZIVTyg', part='contentDetails').execute()

# %%
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'CNB2jhhMHUMlObpR-PenE9kv-vo',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'iaEV3oQTo2sODj2EL0uAK6EilA8',
#    'id': 'UCkUq-s6z57uJFUFBvZIVTyg',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUkUq-s6z57uJFUFBvZIVTyg'}}}]}

# %%
req=youtube.playlistItems().list( playlistId='PLyb_C2HpOQSDlnrNJ_ERqTAkIe21xyRhi',
                                part='snippet',
                                maxResults=50).execute()

# %%
req
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'gtj9aZS2q5irg9FdO7afCSq9360',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'suJy6RQk573Iq-BCxtoGfdrpHs8',
#    'id': 'UEx5Yl9DMkhwT1FTRGxuck5KX0VScVRBa0llMjF4eVJoaS41NkI0NEY2RDEwNTU3Q0M2',
#    'snippet': {'publishedAt': '2020-01-19T13:59:09Z',
#     'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg',
#     'title': 'Serverless Rest API using AWS and Python | Introduction to AWS (Part-1)',
# ...

# %%
def get_channel_videos(channel_id):
    res=youtube.channels().list( id=channel_id,
                                part='contentDetails').execute()
    playlist_id=res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos=[]
    next_page_token=None
    
    while 1:
        res=youtube.playlistItems().list( playlistId=playlist_id, part='snippet', maxResults=50, pageToken=next_page_token).execute()
        
        videos += res['items']
        next_page_token=res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
videos=get_channel_videos('UCkUq-s6z57uJFUFBvZIVTyg')

# %%
len(videos)
# Out:
# 270

# %%
for video in videos:
    print(video['snippet']['title'])
# Out:
# Unit Testing in Python with pytest | Advanced Mocking (Part-10)
# Unit Testing in Python with pytest | Introduction to mock (Part-9)
# Unit Testing in Python with pytest | Parametrizing Unit Tests (Part-4)
# Unit Testing in Python with pytest | Parametrizing Fixtures (Part-8)
# Unit Testing in Python with pytest | Creating Fixture Factory (Part-7)
# Unit Testing in Python with pytest | Creating Custom Fixture (Part-6)
# Unit Testing in Python with pytest | Introduction to Fixtures (Part-5)
# Unit Testing in Python with pytest | Introduction to Markers (Part-3)
# Unit Testing in Python with pytest | Asserting Expected Exceptions (Part-2)
# Unit Testing in Python with pytest | Getting Started (Part-1)
# Plotting Choropleth Maps using Python (Plotly)
# Reading Wikipedia Tables using Python
# Running Shell Commands using Python (Detailed Explanation)
# Automatic Card Generation from Template (Image Manipulation using Python)
# ...

# %%
#xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
videos[0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'uzVxNvbZGfVUqgKNzKCojQvH0VA',
#  'id': 'VVVrVXEtczZ6NTd1SkZVRkJ2WklWVHlnLk00Nkg0R0lkZmww',
#  'snippet': {'publishedAt': '2020-08-30T17:18:06Z',
#   'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg',
#   'title': 'Unit Testing in Python with pytest | Advanced Mocking (Part-10)',
# ...

# %%
req=youtube.videos().list(id=videos[0]['snippet']['resourceId']['videoId'],
                                part='statistics').execute()

# %%
req
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '1ksdtU2eIovCLzkYGSnfp2G2EnM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'stYKfoNsQyRKPwTPpOuPgPNUlr8',
#    'id': 'M46H4GIdfl0',
#    'statistics': {'viewCount': '21385',
#     'likeCount': '324',
#     'favoriteCount': '0',
#     'commentCount': '43'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
def get_videos_stats(video_ids):
    stats=[]
    for i in range(0, len(video_ids), 50):
        res=youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                 part='statistics').execute()
        stats += res['items']
    return stats

# %%
video_ids=list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))

# %%
video_ids
# Out:
# ['M46H4GIdfl0',
#  'dw2eNCzwBkk',
#  'XHEvvY1qjPY',
#  'YmSYW-Ha78M',
#  'TXj1aYldUsI',
#  'pFKHYekCqbU',
#  'jmh1nKz7SjQ',
#  'ArrNCcIXSIk',
#  'R7u8xWXCbGM',
#  'L6N3BgZh2AA',
#  'aJmaw3QKMvk',
#  '7NmBCUOIYPk',
#  'IIiKVaxHCX0',
#  'eiF9cvsX_Jc',
#  'IUna2l6p0nk',
#  'xkcZHqOAgRA',
#  '9Q3du5dVX8I',
#  'g9HyOWr6d9M',
#  'xzlfXSBzhx8',
#  'R4Oz8JUuM4s',
#  'Wgw5ers5jA4',
#  'my2vBYZ1RFw',
#  'Jztj_yuFTlk',
#  'U4dSWJFIQ0A',
#  'WTofttoD2xg',
#  'oYFzQB9zj5I',
#  '8O8VNuYyplU',
#  'vHMvobBbQJc',
#  'BiV-kdQbEo0',
#  'FbfV9N_va7Y',
#  'I93i7KGggcg',
#  'bw1gfnLSmd0',
#  'dT9ymsYVVu8',
#  'sTr30oviyHc',
#  'xZXsR7soexU',
#  'ckNUeTNBwT4',
#  'vDxrmKOJMJ8',
#  'DiXRBYi1KDI',
#  '8NW2IzfoY2Y',
#  'PHX1kraTTrE',
#  'uJC8A_7VZOA',
#  '95y1N6MFCNs',
#  'xeeUgn08F94',
#  'Rw4hrXQi1CI',
#  'hCJpNPsS54Y',
#  'gULdbWqbTIE',
#  'hMIoc2wxTug',
#  'Vc5kGYty18k',
#  'Q2CNZGEH59Q',
#  'j1mh0or2CX8',
#  'kKl7scEW90c',
#  '9n4uJG_Qg44',
#  'HpLJEGApKEs',
#  '7tYEsT2dzlo',
#  'sH5XSdXksAg',
# ...

# %%
stats=get_videos_stats(video_ids)

# %%
len(stats)
# Out:
# 270

# %%
stats[0]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'stYKfoNsQyRKPwTPpOuPgPNUlr8',
#  'id': 'M46H4GIdfl0',
#  'statistics': {'viewCount': '21385',
#   'likeCount': '324',
#   'favoriteCount': '0',
#   'commentCount': '43'}}

# %%
most_disliked=sorted(stats, key=lambda x:int(x['statistics']['likeCount']), reverse=True)

# %%
most_disliked
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'oQqTW0_YdBHJLx3EQQj_LOzN7FE',
#   'id': 'fmf_y8zpOgA',
#   'statistics': {'viewCount': '169373',
#    'likeCount': '2877',
#    'favoriteCount': '0',
#    'commentCount': '291'}},
#  {'kind': 'youtube#video',
#   'etag': 'bDNThsH3A_Q-xuyFSpG5MTPhpSM',
#   'id': 'bytnxnZFLeg',
#   'statistics': {'viewCount': '98844',
#    'likeCount': '2093',
#    'favoriteCount': '0',
#    'commentCount': '260'}},
#  {'kind': 'youtube#video',
#   'etag': 'zGncgF3L8j5KDNl-ecfQTtnBOfw',
#   'id': 'GIywmJbGH-8',
#   'statistics': {'viewCount': '124348',
#    'likeCount': '1863',
#    'favoriteCount': '0',
#    'commentCount': '99'}},
#  {'kind': 'youtube#video',
#   'etag': 'A3QVx8lX2mQvMqOE_F2zJZEu1LU',
#   'id': 'R4Oz8JUuM4s',
#   'statistics': {'viewCount': '65917',
#    'likeCount': '1741',
#    'favoriteCount': '0',
#    'commentCount': '79'}},
#  {'kind': 'youtube#video',
#   'etag': 'l2gucwwVIdQeh_DJXicvDelpRBs',
#   'id': 'BKK5NMDC0fk',
# ...

# %%
#xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
from apiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
CLIENT_SECRET_FILE='client_secret.json'
SCOPES = ['https://www.googleapis.com/auth/youtube']

# %%
flow=InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_FILE, SCOPES)
credentials=flow.run_console()
youtube=build('youtube', 'v3', credentials=credentials)

# %%
youtube

# %%
#xxxxxxxxxxxxxxxxxxxxx

# %%
from apiclient.discovery import build
from datetime import datetime

# %%
start_time=datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time=datetime(year=2008, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

def get_channel(channel_name):
    return youtube.search().list( q=channel_name, type='channel',
                                part='id,snippet').execute()
    

def get_channel_videos(channel_id, part='id,snippet', limit=10):
    res=youtube.channels().list( id=channel_id,
                                part='contentDetails').execute()
    playlist_id=res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos=[]
    next_page_token=None
    
    while 1:
        res=youtube.playlistItems().list( playlistId=playlist_id, part=part, maxResults=min(limit, 50), pageToken=next_page_token).execute()
        
        videos += res['items']
        next_page_token=res.get('nextPageToken')
        
        if next_page_token is None or len(videos) >= limit:
            break
    
    return videos


def parse_publish_timestamp(video):
    return (datetime.strptime(video['snippet']['publisedAt'], '%Y-%m-%dT%H:%M:%S.000Z') + timedelta(hours=5, minutes=30))

# %%
get_channel('pewdiepie')[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 get_channel('pewdiepie')[0]
#
# KeyError: 0

# %%
channel_id=get_channel('pewdiepie')['id']['channelId']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 channel_id=get_channel('pewdiepie')['id']['channelId']
#
# KeyError: 'id'

# %%
videos=get_videos(channelId, limit=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 videos=get_videos(channelId, limit=500)
#
# NameError: name 'get_videos' is not defined

# %%
publish_timestamps=[parse_publish_timestamp(videp) for video in videos]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 publish_timestamps=[parse_publish_timestamp(videp) for video in videos]
#
# Input In [94], in <listcomp>(.0)
# ----> 1 publish_timestamps=[parse_publish_timestamp(videp) for video in videos]
#
# NameError: name 'videp' is not defined

# %%
publish_times=[t.hour + t.minute/60 for t in publish_timestamps]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 publish_times=[t.hour + t.minute/60 for t in publish_timestamps]
#
# NameError: name 'publish_timestamps' is not defined

# %%
import matplotlib.pyplot as plt
# Out:
# D:\Anaconda\lib\site-packages\numpy\__init__.py:148: UserWarning: mkl-service package failed to import, therefore Intel(R) MKL initialization ensuring its correct out-of-the box operation under condition when Gnu OpenMP had already been loaded by Python process is not assured. Please install mkl-service package, see http://github.com/IntelPython/mkl-service
#   from . import _distributor_init
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\numpy\core\__init__.py:22, in <module>
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File D:\Anaconda\lib\site-packages\numpy\core\multiarray.py:12, in <module>
#      10 import warnings
# ---> 12 from . import overrides
#      13 from . import _multiarray_umath
#
# File D:\Anaconda\lib\site-packages\numpy\core\overrides.py:7, in <module>
# ...

# %%
plt.hist(publish_times, bins=24)
plt.xtics(range(25))plt.show()
